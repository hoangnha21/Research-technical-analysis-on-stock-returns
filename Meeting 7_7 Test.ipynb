# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
# Load the dataset from Google Drive
import pandas as pd

dataset_path = '/content/drive/MyDrive/2023SummerResearch/SPY.csv'  # Update the path according to your dataset location
SP500data = pd.read_csv(dataset_path)

# %%
SP500data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-01-10  256.260010  259.160004  255.500000  258.880005  240.387314
# 1    2019-01-11  257.679993  259.010010  257.029999  258.980011  240.480194
# 2    2019-01-14  256.859985  258.299988  256.410004  257.399994  239.013062
# 3    2019-01-15  257.820007  260.700012  257.809998  260.350006  241.752304
# 4    2019-01-16  260.829987  261.970001  260.600006  260.980011  242.337341
# ..          ...         ...         ...         ...         ...         ...
# 775  2022-02-07  449.510010  450.989990  445.850006  447.260010  436.823853
# 776  2022-02-08  446.730011  451.920013  445.220001  450.940002  440.417999
# 777  2022-02-09  455.220001  457.880005  455.010010  457.540009  446.863983
# 778  2022-02-10  451.339996  457.709991  447.200012  449.320007  438.835785
# 779  2022-02-11  449.410004  451.609985  438.940002  440.459991  430.182495
#
#         Volume
# 0     96823900
# 1     73858100
# ...

# %%
#Calculate the 60-period moving average using the 'Close' price column:
lookback = 60
moving_average = SP500data['Close'].rolling(lookback).mean()

# %%
#Calculate the price deviations around the moving average:
deviations = SP500data['Close'] - moving_average

# %%
#Count the number of up periods relative to the total number of periods:
up_periods = np.sum(deviations > 0)
total_periods = len(deviations)

# %%
#Calculate the Trend Intensity Indicator:
trend_intensity_indicator = up_periods / total_periods

# %%
print("Trend Intensity Indicator:", trend_intensity_indicator)
# Out:
# Trend Intensity Indicator: 0.7512820512820513
